# %%
import os

import pandas as pd
import numpy as np
from pandas import DataFrame

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine

from flask import Flask, jsonify, render_template
from flask_sqlalchemy import SQLAlchemy

import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy import Table, Column, Integer, String, MetaData, ForeignKey
from sqlalchemy import inspect


app = Flask(__name__)


engine = create_engine("sqlite:///MMSI_2016.sqlite")


data = engine.execute("SELECT Varible, sum(cast(Factor_Expansión as int)) as Total from MMSI_2016_Demográficos where Demográfico='Estrato_Socioeconómico' group by Varible")


df = DataFrame(data.fetchall())
df.columns = data.keys()
df
# Out:
#       Varible     Total
# 0        Alto   6081339
# 1        Bajo  10491306
# 2  Medio alto  13455125
# 3  Medio bajo  31799699

# %%
db.session.query(Demograficos).column_descriptions()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-41603ffcd006> in <module>
# ----> 1 db.session.query(Demograficos).column_descriptions()
#
# TypeError: 'list' object is not callable

# %%
results = db.session.query(Demograficos.Variable).all()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-cff9b1ed864c> in <module>
# ----> 1 results = db.session.query(Demograficos.Variable).all()
#
# AttributeError: type object 'MMSI_2016_Demográficos' has no attribute 'Variable'

# %%
for result in results:
    print(result)
# Out:
# ...
# ...
# ...
